# %%
from bokeh.plotting import figure, output_file, show
from bokeh.io import output_notebook, save

# %%
import numpy as np

# %%
#Glyphs

PLOT_PATH = '../plots'
p = figure(plot_width=400, plot_height=400)
#eyes
eyes_x = [2, 5] 
eyes_y = [6, 6]
eyes_s = [30, 30]

#mouth
mouth_x = np.arange(2.0 + 0.1, 5.0, 0.1)
mouth_y = np.sqrt(1 + (mouth_x-3.5)**2) 

#nose
nose_s = np.linspace(15, 35, 10)
nose_x = np.ones(10) * 3.5
nose_y = np.linspace(5.5, 3.5, 10)

# add a circle renderer with a size, color, and alpha
p.cross(eyes_x, eyes_y, size=eyes_s, color="green", alpha=0.8, angle=0.25)
p.square(nose_x, nose_y, size=nose_s)
p.line(mouth_x, mouth_y, line_width=10)

filename = f"{PLOT_PATH}/example1.html"
output_file(filename)
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7379">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="cc2ba052-213b-4b9d-bc73-e418ad660b03" data-root-id="7333"></div>

# %%
from bokeh.sampledata.iris import flowers
from bokeh.transform import factor_cmap, factor_mark
from bokeh.models import HoverTool

SPECIES = ['setosa', 'versicolor', 'virginica']
MARKERS = ['hex', 'circle_x', 'triangle']

TOOLTIPS = [("Species", '@species')]

p = figure(title = "Iris Morphology",  tooltips=TOOLTIPS)
p.xaxis.axis_label = 'Petal Length'
p.yaxis.axis_label = 'Sepal Width'

p.scatter("petal_length", "sepal_width", source=flowers, legend_field="species", fill_alpha=0.4, size=12,
          marker=factor_mark('species', MARKERS, SPECIES),
          color=factor_cmap('species', 'Category10_3', SPECIES), hover_color='firebrick')
p.add_tools(HoverTool())

output_file(f"{PLOT_PATH}/iris.html")
show(p)
# Out:
#   <div class="bk-root" id="8756b3e2-5463-4a9b-bf5f-7e9fde061290" data-root-id="7853"></div>

# %%
flowers
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
from kaggle.api.kaggle_api_extended import KaggleApi

DATA_PATH = '../datasets'

api = KaggleApi()
api.authenticate()
datasets = api.dataset_list(search="population")
population_dataset = datasets[0]
api.dataset_download_files(dataset=population_dataset.ref, path=DATA_PATH, unzip=True)

# %%
import pandas as pd
dataframe = pd.read_csv(f"{DATA_PATH}/{population_dataset.ref.split('/')[1].replace('-', '_')}.csv")
dataframe
# Out:
#     Country (or dependency)  Population (2020)  ... Urban Pop %  World Share
# 0                     China         1440297825  ...        61 %      18.47 %
# 1                     India         1382345085  ...        35 %      17.70 %
# 2             United States          331341050  ...        83 %       4.25 %
# 3                 Indonesia          274021604  ...        56 %       3.51 %
# 4                  Pakistan          221612785  ...        35 %       2.83 %
# ..                      ...                ...  ...         ...          ...
# 230              Montserrat               4993  ...        10 %       0.00 %
# 231        Falkland Islands               3497  ...        66 %       0.00 %
# 232                    Niue               1628  ...        46 %       0.00 %
# 233                 Tokelau               1360  ...         0 %       0.00 %
# 234                Holy See                801  ...        N.A.       0.00 %
#
# [235 rows x 11 columns]
